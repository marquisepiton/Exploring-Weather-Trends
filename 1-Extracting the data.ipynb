# %% [markdown]
# # 1st Step: Extracting the data

# %% [markdown]
# ## The first think I did is examine all the csv file and see what kind of  information is in each schema to get a good picture of what kind of data I will be dealing with. I Access the data using sql commands.

# %% [markdown]
# ### 1st Screenshot (city_data): Shows the year, the city, the country that the city resides and the avgerage tempature. To note, it looks like it missing data from the average tempature column.

# %% [markdown]
# ![City_data_pic.JPG](attachment:City_data_pic.JPG)

# %% [markdown]
# ### 2nd Screenshot (city_list): This csv file shows just the city name and the country that it resides in it.

# %% [markdown]
# ![City_list_pic.JPG](attachment:City_list_pic.JPG)

# %% [markdown]
# ### 3nd Screenshot (global_data): This shows the years and average tempature (1750 - 2015)

# %% [markdown]
# ![global_data.JPG](attachment:global_data.JPG)

# %% [markdown]
# ### I extracted all three of the csv files and move on to the next step
